# %%
import pandas as pd

tabela = pd.read_excel("MonitoramentodeClima.xlsx")
display(tabela)
tabela.info()
tabela.to_csv("MonitoramentoDeClimaPasseio.csv")
# Out:
#        ANDAR      TORRE 1      Unnamed: 2         Unnamed: 3 Unnamed: 4  \
# 0        NaN         NOME              ip         mac adress  instalado
# 1    2 andar          NaN             NaN                NaN        NaN
# 2    3 andar   CM-PAS_3T1  192.168.242.13  F0:08:D1:D3:F6:8C        não
# 3    4 andar   CM-PAS_4T1  192.168.242.24     84:CC:A8:5E:E0        não
# 4    5 andar   CM-PAS_5T1  192.168.241.38  24:0A:C4:58:7B:04        não
# 5    6 andar   CM-PAS_6T1  192.168.241.33  24:0A:C4:59:24:B8        não
# 6    7 andar   CM-PAS_7T1  192.168.245.94  AC:67:B2:3C:23:C0        não
# 7    8 andar   CM-PAS_8T1  192.168.241.15  24:0A:C4:58:73:F4        não
# 8    9 andar   CM-PAS_9T1   192.168.242.1  F0:08:D1:D3:52:C8        não
# 9   16 andar  CM-PAS_16T1             NaN                NaN        não
# 10  17 andar  CM-PAS_17T1  192.168.242.24  7C:9E:BD:47:B9:78        não
#
#        TORRE 2      Unnamed: 6         Unnamed: 7 Unnamed: 8
# ...

# %%
import pandas as pd

novo = pd.read_excel("MonitoramentoDeClimaPasseio.csv")
display(novo)
