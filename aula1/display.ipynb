# %%
import pandas as pd

pd. set_option('display.max_columns', None) # or 1000.
pd. set_option('display.max_rows', None)

tabela = pd.read_excel(r"C://Users/gustavo.felix/Downloads/email_curitiba/curitiba_listagem.xlsx")
#tabela = tabela[tabela['Cartao'].notna()]
display(tabela)
#tabela.to_excel("Usuarios Novo.xlsx", index=False)
# Out:
#                           Alan de Oliveira               85230700.0  \
# 0               Wendell de Oliveira Lucena             2138756611.0
# 1                Gabriella Cristini Matoso              135394114.0
# 2                     Celyne Rosa Ferreira              134202254.0
# 3                      Ligia Paula Honorio               97386153.0
# 4         Laiana Barbara Cabral dos Santos              158264811.0
# 5                     Diana de Souza Lopes              137824132.0
# 6               Rebecka Souza Silva Lorenz                7462870.0
# 7                  Pietro Henrique Eugênio              132872007.0
# 8               Naara Rodrigues dos Santos              532054040.0
# 9               Letícia Teresa Suchko Dias              133029214.0
# 10            Nathalia Rodrigues Fernandes              138014177.0
# 11               Giovanna Chaves Da Silva               126182708.0
# 12        Patrícia Lazaroto Andrade Chanan               69505252.0
# ...

# %%
tabela2 = pd.read_excel(r"C://Users/gustavo.felix/Downloads/Colaboradores.xlsx")
#tabela = tabela[tabela['Cartao'].notna()]
display(tabela2)
# Out:
#                                          Nome             CPF
# 0                Alessandro do Amaral Jacaúna  116.236.607-93
# 1                     Alexandre Lopes Godinho  072.349.396-01
# 2       Ana Beatriz Rodrigues Martins Pereira  154.283.087-70
# 3               Ana Caroline Ramos dos Santos  438.249.918-61
# 4              Andre do Espirito Santo Bogado  047.881.907-29
# 5               Anne Carolline Almeida Amaya   117.482.137-09
# 6                Antonio Barbosa Marques Neto  190.170.037-23
# 7                   Bruna Sinder Caputo Neves  163.643.447-98
# 8                   Camilla Santos Gonçalves   118.971.007-28
# 9            Cicero Felipe Bezerra de Andrade  622.464.983-92
# 10         Clarice Ferreira Baptista de Paula  059.183.967-99
# 11           Danyella Louise Costa dos Santos  167.654.187-09
# 12           Emannuelle Angela Rover Bernardo  066.733.499-80
# 13                     Fábio de Queiroz Alves  046.839.661-66
# ...
